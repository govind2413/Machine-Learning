# %%
#importing basic libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn  as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading dataset 
df=pd.read_csv('Wine.csv')

# %%
#To show first 5 records
df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Customer_Segment
# 0   3.92     1065                 1
# 1   3.40     1050                 1
# 2   3.17     1185                 1
# 3   3.45     1480                 1
# 4   2.93      735                 1

# %%
#How many rows and columns
df.shape
# Out:
# (178, 14)

# %%
#To check info of dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
#  13  Customer_Segment      178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
#Applying first step of EDA: Checking null values
df.isnull().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# Customer_Segment        0
# dtype: int64

# %%
#Visualising null values
sns.heatmap(df.isnull())
plt.show()

# %%
#Cross check by datatypes
df.dtypes
# Out:
# Alcohol                 float64
# Malic_Acid              float64
# Ash                     float64
# Ash_Alcanity            float64
# Magnesium                 int64
# Total_Phenols           float64
# Flavanoids              float64
# Nonflavanoid_Phenols    float64
# Proanthocyanins         float64
# Color_Intensity         float64
# Hue                     float64
# OD280                   float64
# Proline                   int64
# Customer_Segment          int64
# dtype: object

# %%
#All columns have been verified to contain only integer and float data types, confirming that there are no null values in the dataset.

# %%
#Next step of EDA: checking duplicate records
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      OD280  Proline  Customer_Segment
# 0     3.92     1065                 1
# 1     3.40     1050                 1
# 2     3.17     1185                 1
# 3     3.45     1480                 1
# 4     2.93      735                 1
# ..     ...      ...               ...
# 173   1.74      740                 3
# 174   1.56      750                 3
# 175   1.56      835                 3
# 176   1.62      840                 3
# 177   1.60      560                 3
#
# [178 rows x 14 columns]

# %%
#check outlier

# %%
#Will seperate input and output 
x=df.drop('Customer_Segment',axis=1)
y=df['Customer_Segment']

# %%
x
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      OD280  Proline
# 0     3.92     1065
# 1     3.40     1050
# 2     3.17     1185
# 3     3.45     1480
# 4     2.93      735
# ..     ...      ...
# 173   1.74      740
# 174   1.56      750
# 175   1.56      835
# 176   1.62      840
# 177   1.60      560
#
# [178 rows x 13 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Customer_Segment, Length: 178, dtype: int64

# %%
#Value counts of output columns
df['Customer_Segment'].value_counts()
# Out:
# Customer_Segment
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='Customer_Segment')
plt.show()

# %%
#Next step of EDA feature scaling 
#before that we will split data into 70% training and 30% testing
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
x_train.shape,x_test.shape
# Out:
# ((124, 13), (54, 13))

# %%
#Will apply StandardScaler on input and output
from sklearn.preprocessing import StandardScaler
#create object of StandardScaler class 
ss=StandardScaler()

# %%
x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %%
x_train
# Out:
# array([[-1.10453814, -0.53090202, -0.13625741, ...,  0.51645351,
#         -0.4182397 , -0.8519466 ],
#        [-0.60884898, -0.79223988, -0.57322083, ...,  0.85655034,
#          0.07607378,  0.73976188],
#        [ 1.17054803, -0.47189024,  1.61159627, ...,  1.23915929,
#          1.13335541,  0.66313697],
#        ...,
#        [ 0.68756884, -0.67421633, -0.42756636, ...,  0.09133246,
#          0.28203774, -0.87981021],
#        [-0.02418996,  0.29526283,  1.24746009, ..., -0.80142174,
#         -0.36331598, -0.43399251],
#        [ 0.12832978, -0.68264658,  0.70125581, ...,  0.68650193,
#         -0.08869738,  1.3248976 ]])

# %%
type(x_train),x_train.ndim
# Out:
# (numpy.ndarray, 2)

# %%
type(x_test),x_test.ndim
# Out:
# (numpy.ndarray, 2)

# %%
#As we have more then 2 class in our output then we will directly apply DecisionTreeClassifier algorithm
from sklearn.tree import DecisionTreeClassifier
#creating object of DecisionTreeClassifier class
dt=DecisionTreeClassifier(random_state=1)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
#feature_importances_ ibuilt method of decisiontreeclassifier class, it show the information gain of each input features
dt.feature_importances_
# Out:
# array([0.06798246, 0.02411111, 0.        , 0.        , 0.        ,
#        0.        , 0.37183384, 0.        , 0.        , 0.02364799,
#        0.        , 0.1055714 , 0.40685321])

# %%
#Creating dictionary
dict={'Input Columns': x.columns,'IG':dt.feature_importances_}
df1=pd.DataFrame(dict)
df1
# Out:
#            Input Columns        IG
# 0                Alcohol  0.067982
# 1             Malic_Acid  0.024111
# 2                    Ash  0.000000
# 3           Ash_Alcanity  0.000000
# 4              Magnesium  0.000000
# 5          Total_Phenols  0.000000
# 6             Flavanoids  0.371834
# 7   Nonflavanoid_Phenols  0.000000
# 8        Proanthocyanins  0.000000
# 9        Color_Intensity  0.023648
# 10                   Hue  0.000000
# 11                 OD280  0.105571
# 12               Proline  0.406853

# %%
#Sorting values accoring to IG column
df1.sort_values('IG',ascending=False,ignore_index=True)
# Out:
#            Input Columns        IG
# 0                Proline  0.406853
# 1             Flavanoids  0.371834
# 2                  OD280  0.105571
# 3                Alcohol  0.067982
# 4             Malic_Acid  0.024111
# 5        Color_Intensity  0.023648
# 6                    Ash  0.000000
# 7           Ash_Alcanity  0.000000
# 8              Magnesium  0.000000
# 9          Total_Phenols  0.000000
# 10  Nonflavanoid_Phenols  0.000000
# 11       Proanthocyanins  0.000000
# 12                   Hue  0.000000

# %%
#Visualise tree
from sklearn import tree
#tree inbuilt class which define in sklearn package 
features=x.columns #features user definded object 
fig=plt.figure(figsize=(20,20)) #change page size
_=tree.plot_tree(dt,feature_names=features,filled=True)

# %%
#Now will test the model on 30% data, by using inbuilt method predict() of DecisionTreeClassifier
y_pred=dt.predict(x_test) #Will return 1,2, and 3
y_test
# Out:
# 161    3
# 117    2
# 19     1
# 69     2
# 53     1
# 138    3
# 112    2
# 14     1
# 160    3
# 107    2
# 11     1
# 4      1
# 108    2
# 42     1
# 84     2
# 113    2
# 152    3
# 35     1
# 105    2
# 31     1
# 51     1
# 126    2
# 130    3
# 73     2
# 40     1
# 162    3
# 47     1
# 29     1
# 16     1
# 147    3
# 97     2
# 159    3
# 151    3
# 5      1
# 120    2
# 94     2
# 91     2
# 81     2
# 114    2
# 48     1
# 54     1
# 59     2
# 165    3
# 39     1
# 56     1
# 44     1
# 78     2
# 33     1
# 18     1
# 58     1
# 127    2
# 172    3
# 148    3
# 12     1
# Name: Customer_Segment, dtype: int64

# %%
#Create a dictionary for checking actual  output and predicted output
dict={'Actual Output':y_test,'Predicted Ouput':y_pred}
df2=pd.DataFrame(dict)
df2
# Out:
#      Actual Output  Predicted Ouput
# 161              3                3
# 117              2                2
# 19               1                1
# 69               2                2
# 53               1                1
# 138              3                3
# 112              2                2
# 14               1                1
# 160              3                3
# 107              2                2
# 11               1                1
# 4                1                2
# 108              2                2
# 42               1                1
# 84               2                2
# 113              2                2
# 152              3                3
# 35               1                1
# 105              2                2
# 31               1                1
# 51               1                1
# 126              2                2
# 130              3                3
# 73               2                1
# 40               1                1
# 162              3                3
# 47               1                1
# 29               1                1
# 16               1                1
# 147              3                3
# 97               2                2
# 159              3                3
# 151              3                3
# 5                1                1
# 120              2                2
# 94               2                2
# 91               2                2
# 81               2                2
# 114              2                2
# 48               1                1
# 54               1                1
# 59               2                3
# 165              3                3
# 39               1                1
# 56               1                1
# 44               1                1
# 78               2                2
# 33               1                1
# 18               1                1
# 58               1                1
# 127              2                2
# 172              3                3
# 148              3                3
# 12               1                1

# %%
#we will now elavaluate the model using confusion_matrix algorithm
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[22  1  0]
#  [ 1 17  1]
#  [ 0  0 12]]

# %%
#Will check report using classification_report algorithm
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.96      0.96      0.96        23
#            2       0.94      0.89      0.92        19
#            3       0.92      1.00      0.96        12
#
#     accuracy                           0.94        54
#    macro avg       0.94      0.95      0.95        54
# weighted avg       0.94      0.94      0.94        54

# %%
#here we can f1 score 0.96,0.92 and 0.96 means 96%,92% and 96%  and accuracy is 0.94 means 94% which is good 
#we will also check with entropy for better score

# %%
dt1=DecisionTreeClassifier(criterion='entropy',random_state=1)

# %%
#train the model
dt1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=1)

# %%
#feature_importances_ inbuilt metohd of DecisionTreeClassifier which give information gain from each input/feature columns
dt1.feature_importances_
# Out:
# array([0.07604035, 0.0167565 , 0.        , 0.        , 0.        ,
#        0.        , 0.41310249, 0.        , 0.        , 0.15626203,
#        0.03424753, 0.        , 0.3035911 ])

# %%
#creating dictionary
dict={'Input columns': x.columns,'IG':dt1.feature_importances_}
df3=pd.DataFrame(dict)
df3
# Out:
#            Input columns        IG
# 0                Alcohol  0.076040
# 1             Malic_Acid  0.016757
# 2                    Ash  0.000000
# 3           Ash_Alcanity  0.000000
# 4              Magnesium  0.000000
# 5          Total_Phenols  0.000000
# 6             Flavanoids  0.413102
# 7   Nonflavanoid_Phenols  0.000000
# 8        Proanthocyanins  0.000000
# 9        Color_Intensity  0.156262
# 10                   Hue  0.034248
# 11                 OD280  0.000000
# 12               Proline  0.303591

# %%
#Sorting values according to IG 
df3.sort_values('IG',ascending=False,ignore_index=True)
# Out:
#            Input columns        IG
# 0             Flavanoids  0.413102
# 1                Proline  0.303591
# 2        Color_Intensity  0.156262
# 3                Alcohol  0.076040
# 4                    Hue  0.034248
# 5             Malic_Acid  0.016757
# 6                    Ash  0.000000
# 7           Ash_Alcanity  0.000000
# 8              Magnesium  0.000000
# 9          Total_Phenols  0.000000
# 10  Nonflavanoid_Phenols  0.000000
# 11       Proanthocyanins  0.000000
# 12                 OD280  0.000000

# %%
#will test the model with 30% data, using inbuilt method predict() of DecisionTreeClassifier
y_pred=dt.predict(x_test)

# %%
#creating a dictionary
dict={'Actual Output': y_test,'Predicted Output':y_pred}
df4=pd.DataFrame(dict)
df4
# Out:
#      Actual Output  Predicted Output
# 161              3                 3
# 117              2                 2
# 19               1                 1
# 69               2                 2
# 53               1                 1
# 138              3                 3
# 112              2                 2
# 14               1                 1
# 160              3                 3
# 107              2                 2
# 11               1                 1
# 4                1                 2
# 108              2                 2
# 42               1                 1
# 84               2                 2
# 113              2                 2
# 152              3                 3
# 35               1                 1
# 105              2                 2
# 31               1                 1
# 51               1                 1
# 126              2                 2
# 130              3                 3
# 73               2                 1
# 40               1                 1
# 162              3                 3
# 47               1                 1
# 29               1                 1
# 16               1                 1
# 147              3                 3
# 97               2                 2
# 159              3                 3
# 151              3                 3
# 5                1                 1
# 120              2                 2
# 94               2                 2
# 91               2                 2
# 81               2                 2
# 114              2                 2
# 48               1                 1
# 54               1                 1
# 59               2                 3
# 165              3                 3
# 39               1                 1
# 56               1                 1
# 44               1                 1
# 78               2                 2
# 33               1                 1
# 18               1                 1
# 58               1                 1
# 127              2                 2
# 172              3                 3
# 148              3                 3
# 12               1                 1

# %%
#will evalute the model using confusion_matrix algorithm
print(confusion_matrix(y_test,y_pred))
# Out:
# [[22  1  0]
#  [ 1 17  1]
#  [ 0  0 12]]

# %%
#checking classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.96      0.96      0.96        23
#            2       0.94      0.89      0.92        19
#            3       0.92      1.00      0.96        12
#
#     accuracy                           0.94        54
#    macro avg       0.94      0.95      0.95        54
# weighted avg       0.94      0.94      0.94        54

# %%
#we got same scores from DecisionTreeClassifier with gini and entropy as well,
#here we can see f1 score 0.96,0.92 and 0.96 means 96%,92% and 96%  and accuracy is 0.94 means 94% which is good 
#we will also check with other algorithm for better score

# %%
#creating a function for train,test and generate report 
def create_model(model):
    #train the model with 70% input and output
    model.fit(x_train,y_train)
    #To test the model with 30% data, machine gives predicted output 
    y_pred=model.predict(x_test)
    #create a report 
    print(confusion_matrix(y_test,y_pred))
    print(classification_report(y_test,y_pred))
    return model

# %%
#Limitations of DecisionTreeClassifier 
#model is overfit,
#To reduced overfit the model, use pruning technique in decisiontree
#how to reduced overfitting in model : use 2 methods:-
#1. max_depth : inbuilt parameter od DecisionTreeClassifier
#2. min_samples_leaf : inbuilt parameters of DecisionTreeClassifier

# %%
#max_depth: max_depth cannot be more than 8 in any dataset.
#create the object of DecisionTreeClassifier class and passing the parameter max_depth

#use hit and trial method : use for loop 
'''
for i in range(1,9): #start i=1 stop=9-1=8 step=+1
    dt2=DecisionTreeClassifier (random_state=1,max_depth=i)
    #here i=1 then i=2 then i=3 and so on
    print("Max Depth:",i)
    #call function and passing the object DecisionTreeClassifier class as a argument
    dt2=create_model(dt2)
'''
dt2=DecisionTreeClassifier(random_state=1,max_depth=6) #by default gini index
#call function and passing the object of DecisionTreeClassifier class as a argument 
dt2=create_model(dt2)
# Out:
# [[22  1  0]
#  [ 1 17  1]
#  [ 0  0 12]]
#               precision    recall  f1-score   support
#
#            1       0.96      0.96      0.96        23
#            2       0.94      0.89      0.92        19
#            3       0.92      1.00      0.96        12
#
#     accuracy                           0.94        54
#    macro avg       0.94      0.95      0.95        54
# weighted avg       0.94      0.94      0.94        54

# %%
#create dictionary
dict={'Input columns':x.columns,'IG':dt2.feature_importances_ }
df1=pd.DataFrame(dict)
df1.sort_values('IG',ascending=False,ignore_index=True)
# Out:
#            Input columns        IG
# 0                Proline  0.406853
# 1             Flavanoids  0.371834
# 2                  OD280  0.105571
# 3                Alcohol  0.067982
# 4             Malic_Acid  0.024111
# 5        Color_Intensity  0.023648
# 6                    Ash  0.000000
# 7           Ash_Alcanity  0.000000
# 8              Magnesium  0.000000
# 9          Total_Phenols  0.000000
# 10  Nonflavanoid_Phenols  0.000000
# 11       Proanthocyanins  0.000000
# 12                   Hue  0.000000

# %%
features=x.columns #features user definded object 
fig=plt.figure(figsize=(20,20)) #change page size
_=tree.plot_tree(dt2,feature_names=features,filled=True)

# %%
#here : max_depth with gini: f1 score is 96%,92% and 96% and accuracy=94%, will also check with entropy as well

# %%
#max_depth with entropy : to reduce overfitting of model
'''
for i in range(1,9): #start i=1 stop=9-1=8 step=+1
    dt2=DecisionTreeClassifier(random_state=1,criterion='entropy',max_depth=i)
    #here i=1 then i=2 then i=3 and so on
    print("Max Depth:",i)
    #call function and passing the object DecisionTreeClassifier class as a argument
    dt2=create_model(dt2)
'''
dt2=DecisionTreeClassifier(random_state=1,criterion='entropy',max_depth=3) #by default gini index
#call function and passing the object of DecisionTreeClassifier class as a argument 
dt2=create_model(dt2)
# Out:
# [[22  1  0]
#  [ 1 18  0]
#  [ 0  1 11]]
#               precision    recall  f1-score   support
#
#            1       0.96      0.96      0.96        23
#            2       0.90      0.95      0.92        19
#            3       1.00      0.92      0.96        12
#
#     accuracy                           0.94        54
#    macro avg       0.95      0.94      0.95        54
# weighted avg       0.95      0.94      0.94        54

# %%
#Conclusion: max_depth with gini: f1 score is 96%,92% and 96% and accuracy=94% (depth=6)
#max_depth with entropy: f1 score is 96%,92% and 96% and accuracy=94% (depth=3)
#We can see that max_depth with entropy is best because depth is 3 hence the process will be faster compare to max_depth with gini depth is 6

# %%
#Second Pruning Technique : To reduce overfitting of model using DecisionTreeClassifier 
#min_samples_leaf : inbuilt parameter of DecisionTreeClassifier class 
#leaf means no any child 

#min samples_leaf>=45 and min_samples_leaf<=100

# %%
'''
for i in range(45,101): #start=45, stop 101-1=100 step=+1
    #create thee object of DecisionTreeClassifier class and passing the parameter
    #min_samples_leaf=i use gini index
    dt3=DecisionTreeClassifier(random_state=1,min_samples_leaf=i) #by default gini index
    print('min samples leaf:',i)
    #call function
    dt3=create_model(dt3)
'''
dt3=DecisionTreeClassifier(random_state=1,min_samples_leaf=51) #by default gini index
#call function
dt3=create_model(dt3)
# Out:
# [[23  0  0]
#  [ 1 18  0]
#  [10  2  0]]
#               precision    recall  f1-score   support
#
#            1       0.68      1.00      0.81        23
#            2       0.90      0.95      0.92        19
#            3       0.00      0.00      0.00        12
#
#     accuracy                           0.76        54
#    macro avg       0.53      0.65      0.58        54
# weighted avg       0.60      0.76      0.67        54

# %%
features=x.columns #features user definded object 
fig=plt.figure(figsize=(20,20)) #change page size
_=tree.plot_tree(dt3,feature_names=features,filled=True)

# %%
#create dictionary
dict={'Input columns':x.columns,'IG':dt3.feature_importances_ }
df1=pd.DataFrame(dict)
df1.sort_values('IG',ascending=False,ignore_index=True)
# Out:
#            Input columns   IG
# 0                Alcohol  1.0
# 1             Malic_Acid  0.0
# 2                    Ash  0.0
# 3           Ash_Alcanity  0.0
# 4              Magnesium  0.0
# 5          Total_Phenols  0.0
# 6             Flavanoids  0.0
# 7   Nonflavanoid_Phenols  0.0
# 8        Proanthocyanins  0.0
# 9        Color_Intensity  0.0
# 10                   Hue  0.0
# 11                 OD280  0.0
# 12               Proline  0.0

# %%
'''
for i in range(45,101): #start=45, stop 101-1=100 step=+1
    #create thee object of DecisionTreeClassifier class and passing the parameter
    #min_samples_leaf=i use gini index
    dt3=DecisionTreeClassifier(random_state=1,criterion='entropy',min_samples_leaf=i) #by default gini index
    print('min samples leaf:',i)
    #call function
    dt3=create_model(dt3)
'''
dt3=DecisionTreeClassifier(random_state=1,criterion='entropy',min_samples_leaf=52) #by default gini index
#call function
dt3=create_model(dt3)
# Out:
# [[23  0  0]
#  [16  0  3]
#  [ 0  0 12]]
#               precision    recall  f1-score   support
#
#            1       0.59      1.00      0.74        23
#            2       0.00      0.00      0.00        19
#            3       0.80      1.00      0.89        12
#
#     accuracy                           0.65        54
#    macro avg       0.46      0.67      0.54        54
# weighted avg       0.43      0.65      0.51        54

# %%
#create dictionary
dict={'Input columns':x.columns,'IG':dt3.feature_importances_ }
df1=pd.DataFrame(dict)
df1.sort_values('IG',ascending=False,ignore_index=True)
# Out:
#            Input columns   IG
# 0             Flavanoids  1.0
# 1                Alcohol  0.0
# 2             Malic_Acid  0.0
# 3                    Ash  0.0
# 4           Ash_Alcanity  0.0
# 5              Magnesium  0.0
# 6          Total_Phenols  0.0
# 7   Nonflavanoid_Phenols  0.0
# 8        Proanthocyanins  0.0
# 9        Color_Intensity  0.0
# 10                   Hue  0.0
# 11                 OD280  0.0
# 12               Proline  0.0

# %%
#min_samples_leaf with gini index: f1 score: 81%, 92% and 0, accuracy=76%
#min_samples_leaf with with entropy : f1 score: 74%, 89% and 0, accuracy=65%

#max_depth with gini: f1 score is 96%,92% and 96% and accuracy=94% (depth=6)
#max_depth with entropy: f1 score is 96%,92% and 96% and accuracy=94% (depth=3)

#best algorithm for this dataset: max_depth with entropy
#got highest score compare as other algorithm 
#f1 score is 96%,92% and 96% and accuracy=94% (depth=3)

# %% [markdown]
# <h2 style="text-align: center;"> Ensembling Technique </h2>

# %%
#Use Ensembling Technique:
#use RandomForestTree : works on bagging concept
from sklearn.ensemble import RandomForestClassifier

# %%
x_train.shape, y_train.shape
# Out:
# ((124, 13), (124,))

# %%
#RandomForestClassifier : train data from many decisiontree
#Atleast 10 decisiontree and max 100 decision tree
#use hit and trail method
'''
for i in range(10,101): #start i=10 stop=101-1=100 step=+1
    #create the object of RandomForestClassifier class and passing the parameter 
    rfc=RandomForestClassifier(random_state=1,n_estimators=i) #by default gini index 
    #n_estimators means number of decision tree 
    print('No of decision:',i)
    #call function
    rfc=create_model(rfc)
'''

#create the object of RandomForestClassifier class and passing the parameter 
rfc=RandomForestClassifier(random_state=1,n_estimators=11) #by default gini index 
#n_estimators means number of decision tree 
#call function
rfc=create_model(rfc)
# Out:
# [[23  0  0]
#  [ 1 18  0]
#  [ 0  0 12]]
#               precision    recall  f1-score   support
#
#            1       0.96      1.00      0.98        23
#            2       1.00      0.95      0.97        19
#            3       1.00      1.00      1.00        12
#
#     accuracy                           0.98        54
#    macro avg       0.99      0.98      0.98        54
# weighted avg       0.98      0.98      0.98        54

# %%
#create dictionary
dict={'Input columns':x.columns,'IG':rfc.feature_importances_}
df6=pd.DataFrame(dict)
df6.sort_values('IG',ascending=False,ignore_index=True)
# Out:
#            Input columns        IG
# 0                Proline  0.246607
# 1             Flavanoids  0.184301
# 2        Color_Intensity  0.128843
# 3                Alcohol  0.103940
# 4                  OD280  0.085048
# 5                    Hue  0.081624
# 6              Magnesium  0.044013
# 7          Total_Phenols  0.040031
# 8             Malic_Acid  0.032332
# 9        Proanthocyanins  0.019504
# 10                   Ash  0.018127
# 11  Nonflavanoid_Phenols  0.011226
# 12          Ash_Alcanity  0.004403

# %%
#checking with entropy 
'''
for i in range(10,101): #start i=10 stop=101-1=100 step=+1
    #create the object of RandomForestClassifier class and passing the parameter 
    rfc=RandomForestClassifier(random_state=1,criterion='entropy',n_estimators=i) 
    #n_estimators means number of decision tree 
    print('No of decision:',i)
    #call function
    rfc=create_model(rfc)
'''
#create the object of RandomForestClassifier class and passing the parameter 
rfc=RandomForestClassifier(random_state=1,criterion='entropy',n_estimators=10)
rfc=create_model(rfc)
# Out:
# [[23  0  0]
#  [ 0 19  0]
#  [ 0  0 12]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        23
#            2       1.00      1.00      1.00        19
#            3       1.00      1.00      1.00        12
#
#     accuracy                           1.00        54
#    macro avg       1.00      1.00      1.00        54
# weighted avg       1.00      1.00      1.00        54

# %%
#create dictionary
dict={'Input columns':x.columns,'IG':rfc.feature_importances_}
df1=pd.DataFrame(dict)
df1.sort_values('IG',ascending=False,ignore_index=True)
# Out:
#            Input columns        IG
# 0             Flavanoids  0.221725
# 1                Proline  0.201137
# 2        Color_Intensity  0.151023
# 3                  OD280  0.095065
# 4              Magnesium  0.078985
# 5                Alcohol  0.065068
# 6                    Hue  0.061340
# 7          Total_Phenols  0.054977
# 8             Malic_Acid  0.028856
# 9                    Ash  0.015279
# 10       Proanthocyanins  0.014847
# 11  Nonflavanoid_Phenols  0.007082
# 12          Ash_Alcanity  0.004615

# %%
#RandomForestClassifier with gini index : f1 score=98%,97% and 100%, accuracy=98%
#RandomForestClassifier with entropy index :  f1 score=100%,100% and 100%, accuracy=100%
#best algorithm in this dataset : RandomForestClassifier with entropy given 100% accuracy and f1 score

# %%
#will also apply the below algorithms on the dataset 
#1. ADA Boost 
#2. gradient Boost
#3. Extreme gradient boost

# %%
#Will apply Gradient boost
#Gradient Boost: It basically focus on short coming errors means fully grown tree

#use inbuilt inner class GradientBoostingClassifier--> inbuilt outer class ensemble
from sklearn.ensemble import GradientBoostingClassifier

# %%
#take atlest 10 decisiontree and maximum 100 decision tree
#use inbuilt parameter n_estimators means no of decision tree of GradientBoostingClassifier
'''
for i in range(10,101): #start i=10 stop 101-1=100 step=+1
    #create the object of GradientBoostingClassifier class and passing the parameter 
    gbc=GradientBoostingClassifier(random_state=1,n_estimators=i) #by default gini index
    print('No of decision tree:',i)
    #call function
    gbc=create_model(gbc)
'''
gbc=GradientBoostingClassifier(random_state=1,n_estimators=10) #by default gini index
#call function
gbc=create_model(gbc)
# Out:
# [[23  0  0]
#  [ 1 18  0]
#  [ 0  0 12]]
#               precision    recall  f1-score   support
#
#            1       0.96      1.00      0.98        23
#            2       1.00      0.95      0.97        19
#            3       1.00      1.00      1.00        12
#
#     accuracy                           0.98        54
#    macro avg       0.99      0.98      0.98        54
# weighted avg       0.98      0.98      0.98        54

# %%
#create dictionary
dict={'Input columns':x.columns,'IG':gbc.feature_importances_}
df1=pd.DataFrame(dict)
df1.sort_values('IG',ascending=False,ignore_index=True)
# Out:
#            Input columns            IG
# 0                Proline  2.994814e-01
# 1             Flavanoids  2.932332e-01
# 2        Color_Intensity  2.707780e-01
# 3                    Hue  4.059970e-02
# 4                    Ash  4.002607e-02
# 5             Malic_Acid  3.095185e-02
# 6                  OD280  2.399470e-02
# 7           Ash_Alcanity  8.226405e-04
# 8   Nonflavanoid_Phenols  8.149425e-05
# 9                Alcohol  3.083899e-05
# 10         Total_Phenols  2.694510e-08
# 11             Magnesium  1.298638e-08
# 12       Proanthocyanins  5.506528e-17

# %%
#Will apply Extreme Gradient Boost (XGB) :
#Extreme Gradient Boost (XGB): This is advanced version of gradient boost.
#1. Multithreading Technique 
#2. It takes less memory space and fast process 
#3. It handles huge amount of data means it deals with large amount of data
#4. It handles outliers because it has inbuilt capacity 
#5. It handles automatic overfitting situation
#6. it handles null values
#Extreme gradient boost is the better version of gradient boost

# %%
#install special inbuilt package: xgboost : it is open source, it is free of cost but install first time 
#!pip install xgboost

# %%
from xgboost import XGBClassifier 
#xgboost inbuilt package--> XGBClassifier inbuilt class -->fit(), predict(), confusion_matrix and classification_report

# %%
#many decisiontree: min =10 and max-100

for i in range(10,101): #start i=10 stop 101-1=100 step=+1
    #create the object of XGBClassifier class 
    xgb=XGBClassifier(random_state=1,n_estimators=i,reg_alpha=1)
    #reg means regularisation  and alpha(lambda) use for reducing overfit model (adds external error)
    #reg_alpha=1 means it handle automatic reduce the overfitting the model
    print('No of decision tree:', i)
    #call function
    xgb=create_model(xgb)
'''
xgb=XGBClassifier(random_state=1,n_estimators=11,reg_alpha=1)
#reg means regularisation  and alpha(lambda) use for reducing overfit model (adds external error)
#reg_alpha=1 means it handle automatic reduce the overfitting the model
xgb=create_model(xgb)
'''
# Out:
# No of decision tree: 10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 10
#       8     print('No of decision tree:', i)
#       9     #call function
# ---> 10     xgb=create_model(xgb)
#      11 '''
#      12 xgb=XGBClassifier(random_state=1,n_estimators=11,reg_alpha=1)
#      13 #reg means regularisation  and alpha(lambda) use for reducing overfit model (adds external error)
#      14 #reg_alpha=1 means it handle automatic reduce the overfitting the model
#      15 xgb=create_model(xgb)
#      16 '''
#
# Cell In[47], line 4, in create_model(model)
#       2 def create_model(model):
#       3     #train the model with 70% input and output
# ----> 4     model.fit(x_train,y_train)
#       5     #To test the model with 30% data, machine gives predicted output
#       6     y_pred=model.predict(x_test)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xgboost\sklearn.py:1640, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1635     expected_classes = self.classes_
#    1636 if (
#    1637     classes.shape != expected_classes.shape
#    1638     or not (classes == expected_classes).all()
#    1639 ):
# -> 1640     raise ValueError(
#    1641         f"Invalid classes inferred from unique values of `y`.  "
#    1642         f"Expected: {expected_classes}, got {classes}"
#    1643     )
#    1645 params = self.get_xgb_params()
#    1647 if callable(self.objective):
#
# ValueError: Invalid classes inferred from unique values of `y`.  Expected: [0 1 2], got [1 2 3]
